# %% [markdown]
# # Fuel Pairs Combinations Train-Test Split
# In this experiment each possible fuel combination has been included as test set and excluded from training set. Each trained model was tried on selected models. Model performances within each trial has been saved as csv file at the end.
#
# File loc: "C:\Users\demir\OneDrive\Desktop\MSc Thesis\Data\!Exp_data\experiment2_results.csv"

# %%
fuel_types = clean_data['fuel_type'].unique()
feature_cols = [
    'h', 'wc', 'vm', 'ac', 'c', 'lhv', 'o', 'n', 's', 'cl',
    'hc', 'oc', 'fc', 'temperature', 'residence_time', 'pressure', 'heat_rate'
]

# These are your original min and max values (as from your summary)
min_values = {
    'wc': 2.6, 'vm': 44.2, 'fc': 3.064326, 'ac': 0.0, 'c': 32.4, 'h': 3.265 , 'lhv': 13.528,
    'o': 7.0, 'n': 0.269662, 's': 0.04642, 'cl': 0.0, 'hc': 0.7, 'oc': 0.0,
    'temperature': 200, 'residence_time': 0.5, 'pressure': 0.5, 'heat_rate': 10
}
max_values = {
    'wc': 10.8, 'vm': 91.735674, 'fc': 44.5, 'ac': 37.52, 'c': 82.3, 'h': 10.13205, 'lhv': 35.8,
    'o': 54.936839, 'n': 3.9, 's': 2.5, 'cl': 1.5, 'hc': 1.857, 'oc': 1.04402, 'temperature': 1200, 'residence_time': 20, 'pressure': 20, 'heat_rate': 1000
}

# Optional: define a margin (e.g. 10%)
margin_ratio = 0.4

# Create expanded bounds
expanded_bounds = {}
for feat in feature_cols:
    min_val = min_values[feat]
    max_val = max_values[feat]
    range_val = max_val - min_val
    new_min = min_val - range_val * margin_ratio
    if new_min < 0:
        new_min = 0
    new_max = max_val + range_val * margin_ratio
    expanded_bounds[feat] = (round(new_min, 3), round(new_max, 3))

# Prepare fake data to fit the scaler
X_bounds = pd.DataFrame({col: [expanded_bounds[col][0], expanded_bounds[col][1]] for col in feature_cols})

# Fit a global scaler based on the expanded bounds
scaler = MinMaxScaler()
scaler.fit(X_bounds)

# Store results
results = []

# Iterate over all combinations of 2 fuel types
for test_comb in combinations(fuel_types, 2):

    # Split data
    train_data = clean_data[~clean_data['fuel_type'].isin(test_comb)].drop(columns=['fuel_type']).reset_index(drop=True)
    test_data = clean_data[clean_data['fuel_type'].isin(test_comb)].drop(columns=['fuel_type']).reset_index(drop=True)

    # Extract features and target
    X_train = train_data.drop(columns=['sample', 'devol_yield'])
    y_train = train_data['devol_yield']
    X_test = test_data.drop(columns=['sample', 'devol_yield'])
    y_test = test_data['devol_yield']

    # Train-test split ratio
    train_ratio = len(X_train) / (len(X_train) + len(X_test))
    test_ratio = 1 - train_ratio

    # Imputation and scaling
    knn_imputer = KNNImputer(n_neighbors=3)
    X_train_imputed = knn_imputer.fit_transform(X_train)
    X_test_imputed = knn_imputer.transform(X_test)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_imputed)
    X_test_scaled = scaler.transform(X_test_imputed)

    X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
    X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

    # Models
    models = {
        "Dummy Mean": DummyRegressor(strategy="mean"),
        "Dummy Median": DummyRegressor(strategy="median"),
        "KNN": KNeighborsRegressor(n_neighbors=5),
        "Linear": LinearRegression(),
        "Ridge": Ridge(alpha=1.0),
        "Lasso": Lasso(alpha=0.1),
        "ElasticNet": ElasticNet(alpha=0.1, l1_ratio=0.5),
        "Decision Tree": DecisionTreeRegressor(max_depth=5),
        "Random Forest": RandomForestRegressor(n_estimators=100, max_depth=5),
        "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, learning_rate=0.1),
        "XGBoost": xgb.XGBRegressor(n_estimators=100, learning_rate=0.1),
        "LightGBM": lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1),
        "Gaussian Process": GaussianProcessRegressor(),
        "SVR": SVR(kernel='rbf', C=1.0, epsilon=0.1),
        "MLP": MLPRegressor(hidden_layer_sizes=(100,), activation='relu', max_iter=2000)
    }

    # Train and evaluate models
    scores = {}
    for model_name, model in models.items():
        model.fit(X_train_scaled, y_train)
        scores[model_name] = model.score(X_test_scaled, y_test)

    # Store results
    results.append({
        "Test Fuel Types": test_comb,
        "Train-Test Ratio": (train_ratio, test_ratio),
        **scores
    })

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Save results to CSV
results_df.to_csv(r"C:\Users\demir\OneDrive\Desktop\MSc Thesis\Final Results\Systematic_Experiments\experiment2_results.csv", index=False)

print("Experiment completed. Results saved.")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1178
# [LightGBM] [Info] Number of data points in the train set: 1417, number of used features: 21
# [LightGBM] [Info] Start training from score 53.213209
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1095
# [LightGBM] [Info] Number of data points in the train set: 1478, number of used features: 21
# [LightGBM] [Info] Start training from score 52.697112
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 1481, number of used features: 21
# [LightGBM] [Info] Start training from score 53.331113
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1166
# [LightGBM] [Info] Number of data points in the train set: 1424, number of used features: 21
# [LightGBM] [Info] Start training from score 53.996577
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1168
# [LightGBM] [Info] Number of data points in the train set: 1370, number of used features: 21
# [LightGBM] [Info] Start training from score 53.197317
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1044
# [LightGBM] [Info] Number of data points in the train set: 1395, number of used features: 21
# [LightGBM] [Info] Start training from score 53.228503
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000228 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1001
# [LightGBM] [Info] Number of data points in the train set: 1375, number of used features: 21
# [LightGBM] [Info] Start training from score 52.906423
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 359
# [LightGBM] [Info] Number of data points in the train set: 1365, number of used features: 21
# [LightGBM] [Info] Start training from score 53.396315
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1063
# [LightGBM] [Info] Number of data points in the train set: 1372, number of used features: 21
# [LightGBM] [Info] Start training from score 54.706476
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000264 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1178
# [LightGBM] [Info] Number of data points in the train set: 1464, number of used features: 21
# [LightGBM] [Info] Start training from score 52.328920
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000239 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 993
# [LightGBM] [Info] Number of data points in the train set: 1416, number of used features: 21
# [LightGBM] [Info] Start training from score 52.321419
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1076
# [LightGBM] [Info] Number of data points in the train set: 1474, number of used features: 21
# [LightGBM] [Info] Start training from score 52.850380
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1067
# [LightGBM] [Info] Number of data points in the train set: 1350, number of used features: 21
# [LightGBM] [Info] Start training from score 54.331583
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1116
# [LightGBM] [Info] Number of data points in the train set: 1422, number of used features: 21
# [LightGBM] [Info] Start training from score 52.656010
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 996
# [LightGBM] [Info] Number of data points in the train set: 1351, number of used features: 21
# [LightGBM] [Info] Start training from score 50.560808
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000215 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1179
# [LightGBM] [Info] Number of data points in the train set: 1412, number of used features: 21
# [LightGBM] [Info] Start training from score 53.161985
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000212 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 1415, number of used features: 21
# [LightGBM] [Info] Start training from score 53.824572
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1266
# [LightGBM] [Info] Number of data points in the train set: 1358, number of used features: 21
# [LightGBM] [Info] Start training from score 54.543090
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1173
# [LightGBM] [Info] Number of data points in the train set: 1304, number of used features: 21
# [LightGBM] [Info] Start training from score 53.726008
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1129
# [LightGBM] [Info] Number of data points in the train set: 1329, number of used features: 21
# [LightGBM] [Info] Start training from score 53.748798
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1090
# [LightGBM] [Info] Number of data points in the train set: 1309, number of used features: 21
# [LightGBM] [Info] Start training from score 53.418428
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000141 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 358
# [LightGBM] [Info] Number of data points in the train set: 1299, number of used features: 21
# [LightGBM] [Info] Start training from score 53.937153
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1162
# [LightGBM] [Info] Number of data points in the train set: 1306, number of used features: 21
# [LightGBM] [Info] Start training from score 55.310625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1173
# [LightGBM] [Info] Number of data points in the train set: 1398, number of used features: 21
# [LightGBM] [Info] Start training from score 52.781065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000263 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1167
# [LightGBM] [Info] Number of data points in the train set: 1350, number of used features: 21
# [LightGBM] [Info] Start training from score 52.789275
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000199 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1159
# [LightGBM] [Info] Number of data points in the train set: 1408, number of used features: 21
# [LightGBM] [Info] Start training from score 53.323758
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1170
# [LightGBM] [Info] Number of data points in the train set: 1284, number of used features: 21
# [LightGBM] [Info] Start training from score 54.926813
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1277
# [LightGBM] [Info] Number of data points in the train set: 1356, number of used features: 21
# [LightGBM] [Info] Start training from score 53.138080
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000230 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1083
# [LightGBM] [Info] Number of data points in the train set: 1285, number of used features: 21
# [LightGBM] [Info] Start training from score 50.961901
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1095
# [LightGBM] [Info] Number of data points in the train set: 1476, number of used features: 21
# [LightGBM] [Info] Start training from score 53.282510
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1167
# [LightGBM] [Info] Number of data points in the train set: 1419, number of used features: 21
# [LightGBM] [Info] Start training from score 53.948367
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000758 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1167
# [LightGBM] [Info] Number of data points in the train set: 1365, number of used features: 21
# [LightGBM] [Info] Start training from score 53.144271
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1045
# [LightGBM] [Info] Number of data points in the train set: 1390, number of used features: 21
# [LightGBM] [Info] Start training from score 53.176523
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000274 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1002
# [LightGBM] [Info] Number of data points in the train set: 1370, number of used features: 21
# [LightGBM] [Info] Start training from score 52.852509
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 359
# [LightGBM] [Info] Number of data points in the train set: 1360, number of used features: 21
# [LightGBM] [Info] Start training from score 53.343806
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1065
# [LightGBM] [Info] Number of data points in the train set: 1367, number of used features: 21
# [LightGBM] [Info] Start training from score 54.659028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1180
# [LightGBM] [Info] Number of data points in the train set: 1459, number of used features: 21
# [LightGBM] [Info] Start training from score 52.276316
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 995
# [LightGBM] [Info] Number of data points in the train set: 1411, number of used features: 21
# [LightGBM] [Info] Start training from score 52.266999
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000200 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1164
# [LightGBM] [Info] Number of data points in the train set: 1469, number of used features: 21
# [LightGBM] [Info] Start training from score 52.799909
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1069
# [LightGBM] [Info] Number of data points in the train set: 1345, number of used features: 21
# [LightGBM] [Info] Start training from score 54.281965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1118
# [LightGBM] [Info] Number of data points in the train set: 1417, number of used features: 21
# [LightGBM] [Info] Start training from score 52.603001
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 996
# [LightGBM] [Info] Number of data points in the train set: 1346, number of used features: 21
# [LightGBM] [Info] Start training from score 50.497220
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1165
# [LightGBM] [Info] Number of data points in the train set: 1422, number of used features: 21
# [LightGBM] [Info] Start training from score 54.606033
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1256
# [LightGBM] [Info] Number of data points in the train set: 1368, number of used features: 21
# [LightGBM] [Info] Start training from score 53.829662
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000219 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1043
# [LightGBM] [Info] Number of data points in the train set: 1393, number of used features: 21
# [LightGBM] [Info] Start training from score 53.849544
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000244 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1006
# [LightGBM] [Info] Number of data points in the train set: 1373, number of used features: 21
# [LightGBM] [Info] Start training from score 53.536041
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000176 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 359
# [LightGBM] [Info] Number of data points in the train set: 1363, number of used features: 21
# [LightGBM] [Info] Start training from score 54.031272
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1077
# [LightGBM] [Info] Number of data points in the train set: 1370, number of used features: 21
# [LightGBM] [Info] Start training from score 55.340101
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1087
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 21
# [LightGBM] [Info] Start training from score 52.919420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1078
# [LightGBM] [Info] Number of data points in the train set: 1414, number of used features: 21
# [LightGBM] [Info] Start training from score 52.931954
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1073
# [LightGBM] [Info] Number of data points in the train set: 1472, number of used features: 21
# [LightGBM] [Info] Start training from score 53.437577
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000234 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1157
# [LightGBM] [Info] Number of data points in the train set: 1348, number of used features: 21
# [LightGBM] [Info] Start training from score 54.974993
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1188
# [LightGBM] [Info] Number of data points in the train set: 1420, number of used features: 21
# [LightGBM] [Info] Start training from score 53.264436
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1091
# [LightGBM] [Info] Number of data points in the train set: 1349, number of used features: 21
# [LightGBM] [Info] Start training from score 51.198151
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1175
# [LightGBM] [Info] Number of data points in the train set: 1311, number of used features: 21
# [LightGBM] [Info] Start training from score 54.574160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000179 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1032
# [LightGBM] [Info] Number of data points in the train set: 1336, number of used features: 21
# [LightGBM] [Info] Start training from score 54.580959
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 996
# [LightGBM] [Info] Number of data points in the train set: 1316, number of used features: 21
# [LightGBM] [Info] Start training from score 54.264994
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 1306, number of used features: 21
# [LightGBM] [Info] Start training from score 54.787420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1062
# [LightGBM] [Info] Number of data points in the train set: 1313, number of used features: 20
# [LightGBM] [Info] Start training from score 56.149037
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000225 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1076
# [LightGBM] [Info] Number of data points in the train set: 1405, number of used features: 21
# [LightGBM] [Info] Start training from score 53.577180
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1067
# [LightGBM] [Info] Number of data points in the train set: 1357, number of used features: 21
# [LightGBM] [Info] Start training from score 53.613508
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1062
# [LightGBM] [Info] Number of data points in the train set: 1415, number of used features: 21
# [LightGBM] [Info] Start training from score 54.111562
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000224 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1169
# [LightGBM] [Info] Number of data points in the train set: 1291, number of used features: 21
# [LightGBM] [Info] Start training from score 55.781594
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000212 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1173
# [LightGBM] [Info] Number of data points in the train set: 1363, number of used features: 21
# [LightGBM] [Info] Start training from score 53.956894
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1019
# [LightGBM] [Info] Number of data points in the train set: 1292, number of used features: 21
# [LightGBM] [Info] Start training from score 51.837502
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1128
# [LightGBM] [Info] Number of data points in the train set: 1282, number of used features: 21
# [LightGBM] [Info] Start training from score 53.751450
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1088
# [LightGBM] [Info] Number of data points in the train set: 1262, number of used features: 21
# [LightGBM] [Info] Start training from score 53.408819
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000207 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 21
# [LightGBM] [Info] Start training from score 53.946940
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1169
# [LightGBM] [Info] Number of data points in the train set: 1259, number of used features: 21
# [LightGBM] [Info] Start training from score 55.371631
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1170
# [LightGBM] [Info] Number of data points in the train set: 1351, number of used features: 21
# [LightGBM] [Info] Start training from score 52.749916
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1167
# [LightGBM] [Info] Number of data points in the train set: 1303, number of used features: 21
# [LightGBM] [Info] Start training from score 52.757274
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000237 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1155
# [LightGBM] [Info] Number of data points in the train set: 1361, number of used features: 21
# [LightGBM] [Info] Start training from score 53.311578
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1163
# [LightGBM] [Info] Number of data points in the train set: 1237, number of used features: 21
# [LightGBM] [Info] Start training from score 54.974321
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000234 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1093
# [LightGBM] [Info] Number of data points in the train set: 1309, number of used features: 21
# [LightGBM] [Info] Start training from score 53.118750
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1078
# [LightGBM] [Info] Number of data points in the train set: 1238, number of used features: 21
# [LightGBM] [Info] Start training from score 50.858845
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 835
# [LightGBM] [Info] Number of data points in the train set: 1287, number of used features: 21
# [LightGBM] [Info] Start training from score 53.438514
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 325
# [LightGBM] [Info] Number of data points in the train set: 1277, number of used features: 21
# [LightGBM] [Info] Start training from score 53.966332
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1022
# [LightGBM] [Info] Number of data points in the train set: 1284, number of used features: 21
# [LightGBM] [Info] Start training from score 55.363178
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000291 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 960
# [LightGBM] [Info] Number of data points in the train set: 1376, number of used features: 21
# [LightGBM] [Info] Start training from score 52.789661
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 945
# [LightGBM] [Info] Number of data points in the train set: 1328, number of used features: 21
# [LightGBM] [Info] Start training from score 52.798317
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1038
# [LightGBM] [Info] Number of data points in the train set: 1386, number of used features: 21
# [LightGBM] [Info] Start training from score 53.340906
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1122
# [LightGBM] [Info] Number of data points in the train set: 1262, number of used features: 21
# [LightGBM] [Info] Start training from score 54.973592
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 960
# [LightGBM] [Info] Number of data points in the train set: 1334, number of used features: 21
# [LightGBM] [Info] Start training from score 53.152835
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 969
# [LightGBM] [Info] Number of data points in the train set: 1263, number of used features: 21
# [LightGBM] [Info] Start training from score 50.939578
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 287
# [LightGBM] [Info] Number of data points in the train set: 1257, number of used features: 21
# [LightGBM] [Info] Start training from score 53.625757
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1066
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 21
# [LightGBM] [Info] Start training from score 55.046591
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000171 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 923
# [LightGBM] [Info] Number of data points in the train set: 1356, number of used features: 21
# [LightGBM] [Info] Start training from score 52.456596
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 910
# [LightGBM] [Info] Number of data points in the train set: 1308, number of used features: 21
# [LightGBM] [Info] Start training from score 52.453162
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1005
# [LightGBM] [Info] Number of data points in the train set: 1366, number of used features: 21
# [LightGBM] [Info] Start training from score 53.018350
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000171 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1082
# [LightGBM] [Info] Number of data points in the train set: 1242, number of used features: 21
# [LightGBM] [Info] Start training from score 54.645123
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 922
# [LightGBM] [Info] Number of data points in the train set: 1314, number of used features: 21
# [LightGBM] [Info] Start training from score 52.814651
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000307 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 929
# [LightGBM] [Info] Number of data points in the train set: 1243, number of used features: 21
# [LightGBM] [Info] Start training from score 50.546466
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 361
# [LightGBM] [Info] Number of data points in the train set: 1254, number of used features: 21
# [LightGBM] [Info] Start training from score 55.596914
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 370
# [LightGBM] [Info] Number of data points in the train set: 1346, number of used features: 21
# [LightGBM] [Info] Start training from score 52.950062
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 358
# [LightGBM] [Info] Number of data points in the train set: 1298, number of used features: 21
# [LightGBM] [Info] Start training from score 52.964850
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 359
# [LightGBM] [Info] Number of data points in the train set: 1356, number of used features: 21
# [LightGBM] [Info] Start training from score 53.512319
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 355
# [LightGBM] [Info] Number of data points in the train set: 1232, number of used features: 21
# [LightGBM] [Info] Start training from score 55.202015
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 1304, number of used features: 21
# [LightGBM] [Info] Start training from score 53.326757
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 356
# [LightGBM] [Info] Number of data points in the train set: 1233, number of used features: 21
# [LightGBM] [Info] Start training from score 51.069665
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1068
# [LightGBM] [Info] Number of data points in the train set: 1353, number of used features: 21
# [LightGBM] [Info] Start training from score 54.280929
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1137
# [LightGBM] [Info] Number of data points in the train set: 1305, number of used features: 21
# [LightGBM] [Info] Start training from score 54.344589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1071
# [LightGBM] [Info] Number of data points in the train set: 1363, number of used features: 21
# [LightGBM] [Info] Start training from score 54.830535
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000172 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1255
# [LightGBM] [Info] Number of data points in the train set: 1239, number of used features: 21
# [LightGBM] [Info] Start training from score 56.642612
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000176 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 993
# [LightGBM] [Info] Number of data points in the train set: 1311, number of used features: 21
# [LightGBM] [Info] Start training from score 54.698249
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000167 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1085
# [LightGBM] [Info] Number of data points in the train set: 1240, number of used features: 21
# [LightGBM] [Info] Start training from score 52.532428
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000196 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 988
# [LightGBM] [Info] Number of data points in the train set: 1397, number of used features: 21
# [LightGBM] [Info] Start training from score 51.876838
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000249 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1082
# [LightGBM] [Info] Number of data points in the train set: 1455, number of used features: 21
# [LightGBM] [Info] Start training from score 52.430428
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1166
# [LightGBM] [Info] Number of data points in the train set: 1331, number of used features: 21
# [LightGBM] [Info] Start training from score 53.893651
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1012
# [LightGBM] [Info] Number of data points in the train set: 1403, number of used features: 21
# [LightGBM] [Info] Start training from score 52.217860
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1014
# [LightGBM] [Info] Number of data points in the train set: 1332, number of used features: 21
# [LightGBM] [Info] Start training from score 50.069418
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000245 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1074
# [LightGBM] [Info] Number of data points in the train set: 1407, number of used features: 21
# [LightGBM] [Info] Start training from score 52.426343
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1162
# [LightGBM] [Info] Number of data points in the train set: 1283, number of used features: 21
# [LightGBM] [Info] Start training from score 53.943914
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 997
# [LightGBM] [Info] Number of data points in the train set: 1355, number of used features: 21
# [LightGBM] [Info] Start training from score 52.206089
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1003
# [LightGBM] [Info] Number of data points in the train set: 1284, number of used features: 21
# [LightGBM] [Info] Start training from score 49.976679
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1152
# [LightGBM] [Info] Number of data points in the train set: 1341, number of used features: 21
# [LightGBM] [Info] Start training from score 54.455161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000345 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1087
# [LightGBM] [Info] Number of data points in the train set: 1413, number of used features: 21
# [LightGBM] [Info] Start training from score 52.762618
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000200 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1008
# [LightGBM] [Info] Number of data points in the train set: 1342, number of used features: 21
# [LightGBM] [Info] Start training from score 50.659006
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1086
# [LightGBM] [Info] Number of data points in the train set: 1289, number of used features: 21
# [LightGBM] [Info] Start training from score 54.305475
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1070
# [LightGBM] [Info] Number of data points in the train set: 1218, number of used features: 21
# [LightGBM] [Info] Start training from score 52.077638
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1008
# [LightGBM] [Info] Number of data points in the train set: 1290, number of used features: 21
# [LightGBM] [Info] Start training from score 50.356412
# Experiment completed. Results saved.
